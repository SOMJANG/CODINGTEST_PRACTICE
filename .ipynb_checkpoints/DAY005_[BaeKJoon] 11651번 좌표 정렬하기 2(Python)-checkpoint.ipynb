# %% [markdown]
# ## 2020년 2월 11일 화요일
# ### 백준 11650번: 좌표 정렬하기
# ### 문제 : https://www.acmicpc.net/problem/11651
# ### 블로그 : https://somjang.tistory.com/entry/BaeKJoon-11650%EB%B2%88-%EC%A2%8C%ED%91%9C-%EC%A0%95%EB%A0%AC%ED%95%98%EA%B8%B0-Python

# %% [markdown]
# ### 첫번째 시도

# %% [markdown]
# 입력 받은 수를 list로 만들고
# python의 sorted함수를 사용하서 정렬 후 출력해 보았습니다.

# %%
N = int(input())

nums = []
for i in range(N):
    [a, b] = map(int, input().split())
    nums.append([a, b])
    
nums = sorted(nums)

for i in range(N):
    print(nums[i][0], nums[i][1])
# Out:
# 5
# 3 4
# 1 1
# 1 -1
# 2 2
# 3 3
# 1 -1
# 1 1
# 2 2
# 3 3
# 3 4

# %% [markdown]
# ### PyPy3로 제출하여 성공!
