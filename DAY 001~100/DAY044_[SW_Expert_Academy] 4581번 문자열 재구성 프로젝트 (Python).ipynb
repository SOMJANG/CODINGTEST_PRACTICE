# %% [markdown]
# ## 2020년 3월 21일 토요일
# ### SW Expert Academy - 4581번 문자열 재구성 프로젝트
# ### 문제 :https://swexpertacademy.com/main/code/problem/problemDetail.do?contestProbId=AWQA81faAK0DFAWh&categoryId=AWQA81faAK0DFAWh&categoryType=CODE
# ### 블로그 : https://somjang.tistory.com/entry/SWExpertAcademy-4581%EB%B2%88-%EB%AC%B8%EC%9E%90%EC%97%B4-%EC%9E%AC%EA%B5%AC%EC%84%B1-%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8-Python

# %% [markdown]
# ### 첫번째 시도

# %%
print('a' > 'b')
# Out:
# False

# %%
input_text = 'acdbcb'

text_list = list(input_text)

front_index = 0
last_index = len(text_list)-1

answer = []

while(True):
    if front_index == last_index:
        answer.append(text_list[front_index])
        break
    
    if text_list[front_index] < text_list[last_index]:
        answer.append(text_list[front_index])
        front_index = front_index + 1
        print("if ", text_list[front_index], text_list[last_index], front_index, last_index)
    elif text_list[front_index] > text_list[last_index]:
        answer.append(text_list[last_index])
        last_index= last_index - 1
        print("elif ", text_list[front_index], text_list[last_index], front_index, last_index)
    elif text_list[front_index] == text_list[last_index]:
        if front_index == last_index-1:
            answer.append(text_list[front_index])
            answer.append(text_list[last_index])
            last_index = last_index - 1
            print("elif if ", text_list[front_index], text_list[last_index], front_index, last_index)
        else:
            if text_list[front_index + 1] <= text_list[last_index - 1]:
                answer.append(text_list[front_index])
                front_index = front_index + 1
                print("elif else if ", text_list[front_index], text_list[last_index], front_index, last_index)
            elif text_list[front_index + 1] > text_list[last_index - 1]:
                answer.append(text_list[last_index])
                last_index = last_index - 1
                print("elif else elif ", text_list[front_index], text_list[last_index], front_index, last_index)
print(answer)
# Out:
# if  c b 1 5
# elif  c c 1 4
# elif else elif  c b 1 3
# elif  c d 1 2
# if  d d 2 2
# ['a', 'b', 'c', 'b', 'c', 'd']

# %%
test_case_num = int(input())

for i in range(test_case_num):
    input_text = str(input())

    text_list = list(input_text)

    front_index = 0
    last_index = len(text_list)-1

    answer = []

    while(True):
        if front_index == last_index:
            answer.append(text_list[front_index])
            break

        if text_list[front_index] < text_list[last_index]:
            answer.append(text_list[front_index])
            front_index = front_index + 1
#             print("if ", text_list[front_index], text_list[last_index], front_index, last_index)
        elif text_list[front_index] > text_list[last_index]:
            answer.append(text_list[last_index])
            last_index= last_index - 1
#             print("elif ", text_list[front_index], text_list[last_index], front_index, last_index)
        elif text_list[front_index] == text_list[last_index]:
            if front_index == last_index-1:
                answer.append(text_list[last_index])
                last_index = last_index - 1
#                 print("elif if ", text_list[front_index], text_list[last_index], front_index, last_index)
            else:
                if text_list[front_index + 1] <= text_list[last_index - 1]:
                    answer.append(text_list[front_index])
                    front_index = front_index + 1
#                     print("elif else if ", text_list[front_index], text_list[last_index], front_index, last_index)
                elif text_list[front_index + 1] > text_list[last_index - 1]:
                    answer.append(text_list[last_index])
                    last_index = last_index - 1
#                     print("elif else elif ", text_list[front_index], text_list[last_index], front_index, last_index)
    print("#{} {}".format(i+1, ''.join(answer)))
# Out:
# 1
# bacbab
# #1 bababc

# %%
test_case_num = int(input())

for i in range(test_case_num):
    input_text = str(input())

    text_list = list(input_text)

    front_index = 0
    last_index = len(text_list)-1

    answer = []

    while(True):
        if front_index == last_index:
            answer.append(text_list[front_index])
            break

        if text_list[front_index] < text_list[last_index]:
            answer.append(text_list[front_index])
            front_index = front_index + 1
#             print("if ", text_list[front_index], text_list[last_index], front_index, last_index)
        elif text_list[front_index] > text_list[last_index]:
            answer.append(text_list[last_index])
            last_index= last_index - 1
#             print("elif ", text_list[front_index], text_list[last_index], front_index, last_index)
        elif text_list[front_index] == text_list[last_index]:
            if front_index == last_index-1:
                answer.append(text_list[last_index])
                last_index = last_index - 1
#                 print("elif if ", text_list[front_index], text_list[last_index], front_index, last_index)
            else:
                if text_list[front_index + 1] <= text_list[last_index - 1]:
                    answer.append(text_list[front_index])
                    front_index = front_index + 1
#                     print("elif else if ", text_list[front_index], text_list[last_index], front_index, last_index)
                elif text_list[front_index + 1] > text_list[last_index - 1]:
                    answer.append(text_list[last_index])
                    last_index = last_index - 1
#                     print("elif else elif ", text_list[front_index], text_list[last_index], front_index, last_index)
    print("#{} {}".format(i+1, ''.join(answer)))
# Out:
# 1
# zaz
# #1 zaz

# %%
test_case_num = int(input())

for i in range(test_case_num):
    input_text = str(input())

    text_list = list(input_text)

    front_index = 0
    last_index = len(text_list)-1

    answer = []

    while(True):
        if front_index == last_index:
            answer.append(text_list[front_index])
            break

        if text_list[front_index] < text_list[last_index]:
            answer.append(text_list[front_index])
            front_index = front_index + 1
#             print("if ", text_list[front_index], text_list[last_index], front_index, last_index)
        elif text_list[front_index] > text_list[last_index]:
            answer.append(text_list[last_index])
            last_index= last_index - 1
            
        elif text_list[front_index] == text_list[last_index]:
            if front_index == last_index-1:
                answer.append(text_list[last_index])
                last_index = last_index - 1
            else:
                temp_index = 0
                change_index = last_index
                
                while(True):
                    if temp_front + 1 > len(text_list) - 1 or temp_last -1 < 0:
                        break
                    temp_front = front_index
                    temp_last = last_index
                    
                    if text_list[temp_front + temp_index + 1] < text_list[temp_last - temp_index - 1]:
                        change_index = front_index
                        break
                    elif text_list[temp_front + temp_index + 1] > text_list[temp_last - temp_index -1]:
                        change_index = last_index
                        break
                    temp_index = temp_index + 1
                        
                answer.append(text_list[change_index]) 
                if change_index == front_index:
                    front_index = front_index + 1
                else:
                    last_index = last_index - 1
    print("#{} {}".format(i+1, ''.join(answer)))
# Out:
# 2
# aaaa
# #1 aaaa
# agagaga
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-57-d9a2004a50da> in <module>
#      38                     temp_last = last_index
#      39
# ---> 40                     if text_list[temp_front + temp_index + 1] < text_list[temp_last - temp_index - 1]:
#      41                         change_index = front_index
#      42                         break
#
# IndexError: list index out of range

# %%
input_num = int(input())

for i in range(input_num):
    input_text = str(input())
    text = list(input_text)
    
    answer = []
    
    front = 0
    end = len(text) - 1
    
    while(True):
        print("while front, end", front, end)
        if front == end:
            print("here")
            answer.append(text[front])
            break
        
        if text[front] < text[end]:
            print("<")
            answer.append(text[front])
            front = front + 1
        elif text[front] > text[end]:
            print(">")
            answer.append(text[end])
            end = end - 1
        elif text[front] == text[end]:
            temp_front = front
            temp_end = end
            
            change_index = end
            
            while(True):
                print(temp_front, temp_end, text[temp_front], text[temp_end])
                if temp_front == end and temp_end == front:
                    break
                if text[temp_front] < text[temp_end]:
                    print("<", temp_front, temp_end)
                    change_index = front
                    break
                elif text[temp_front] > text[temp_end]:
                    print("<", temp_front, temp_end)
                    change_index = end
                    break
                temp_front = temp_front + 1
                temp_end = temp_end - 1
            print("append")
            answer.append(text[change_index])
            
            if change_index == front:
                print("front + 1")
                front = front + 1
            elif change_index == end:
                print("end - 1")
                end = end - 1
    print("".join(answer))
# Out:
# 1
# ecekkkececccceee
# while front, end 0 15
# 0 15 e e
# 1 14 c e
# < 1 14
# append
# front + 1
# while front, end 1 15
# <
# while front, end 2 15
# 2 15 e e
# 3 14 k e
# < 3 14
# append
# end - 1
# while front, end 2 14
# 2 14 e e
# 3 13 k e
# < 3 13
# append
# end - 1
# while front, end 2 13
# 2 13 e e
# 3 12 k c
# < 3 12
# append
# end - 1
# while front, end 2 12
# >
# while front, end 2 11
# >
# while front, end 2 10
# >
# while front, end 2 9
# >
# while front, end 2 8
# 2 8 e e
# 3 7 k c
# < 3 7
# append
# end - 1
# while front, end 2 7
# >
# while front, end 2 6
# 2 6 e e
# 3 5 k k
# 4 4 k k
# 5 3 k k
# 6 2 e e
# append
# end - 1
# while front, end 2 5
# <
# while front, end 3 5
# 3 5 k k
# 4 4 k k
# 5 3 k k
# append
# end - 1
# while front, end 3 4
# 3 4 k k
# 4 3 k k
# append
# end - 1
# while front, end 3 3
# here
# eceeecccceceekkk

# %%
input_num = int(input())

for i in range(input_num):
    input_text = str(input())
    text = list(input_text)
    
    answer = []
    
    front = 0
    end = len(text) - 1
    
    while(True):
        if front == end:
            answer.append(text[front])
            break
        
        if text[front] < text[end]:
            answer.append(text[front])
            front = front + 1
        elif text[front] > text[end]:
            answer.append(text[end])
            end = end - 1
        elif text[front] == text[end]:
            temp_front = front
            temp_end = end
            
            change_index = end
            
            while(True):
                if temp_front == end and temp_end == front:
                    break
                if text[temp_front] < text[temp_end]:
                    change_index = front
                    break
                elif text[temp_front] > text[temp_end]:
                    change_index = end
                    break
                temp_front = temp_front + 1
                temp_end = temp_end - 1
            answer.append(text[change_index])
            
            if change_index == front:
                front = front + 1
            elif change_index == end:
                end = end - 1
    print("#{} {}".format(i+1, "".join(answer)))
